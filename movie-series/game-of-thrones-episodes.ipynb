# %% [markdown]
# # Game of Thrones Episodes

# %% [markdown]
# Library dan/atau module yang digunakan dalam latihan kali ini ialah:
#
# - request (seperti httr pada R)
# - BeautifulSoup (seperti rvest pada R)
# - pandas (seperti tibble pada R)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
res = requests.get("https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_episodes")

# %%
page = BeautifulSoup(res.text, "html.parser")

# %%
episode_tables = page.find_all("table", class_ = "wikitable plainrowheaders wikiepisodetable")

# %%
episodes = []
for table in episode_tables:
    headers = []
    for header in table.find("tr").find_all("th"):
        headers.append(header.text)
    for row in table.find_all("tr")[1:]:
        values = []
        value = row.find_all("td")
        for col in row.find_all(["th", "td"]):
            values.append(col.text)
        episodes_dict = { headers[i] : values[i] for i in range(len(values))}
        episodes.append(episodes_dict)

# %%
df = pd.DataFrame(episodes)
df
# Out:
#    No.overall No. inseason                                    Title  \
# 0           1            1                       "Winter Is Coming"
# 1           2            2                          "The Kingsroad"
# 2           3            3                              "Lord Snow"
# 3           4            4  "Cripples, Bastards, and Broken Things"
# 4           5            5                  "The Wolf and the Lion"
# ..        ...          ...                                      ...
# 72         73            6                        "The Iron Throne"
# 73        NaN          NaN       Game of Thrones: A Day in the Life
# 74        NaN          NaN                                      NaN
# 75        NaN          NaN          Game of Thrones: The Last Watch
# 76        NaN          NaN                                      NaN
#
#                     Directed by                   Written by  \
# 0                Tim Van Patten  David Benioff & D. B. Weiss
# ...

# %%
df.to_csv("./game-of-thrones-episodes.csv")
